# %% [markdown]
# # Tax Assistant Data Scrapper

# %% [markdown]
# ## Import Libaries

# %%
import requests # pip install requests
from bs4 import BeautifulSoup #pip install beautifulsoup4 #pip install lxml
import os
import re

# %% [markdown]
# ## Get URLs from sitemap

# %%
# Path to the local sitemap.xml file in your project folder
sitemap_file_path = './sitemap_us.xml' # got from here: https://www.xml-sitemaps.com/details-www.revenue.ie-492529958.html

with open(sitemap_file_path, 'r', encoding='utf-8') as file:
    sitemap_content = file.read()

soup = BeautifulSoup(sitemap_content, 'lxml-xml')  # Use 'lxml-xml' as the parser

# Extract URLs from the local sitemap.xml
urls = [loc.text for loc in soup.find_all('loc')]
print(len(urls))
# Out:
# 500

# %% [markdown]
# ## Crawl URLs & Get Text Data

# %%
def url_to_filename(url):
    # Remove the "http://" or "https://" part of the URL
    url_without_protocol = re.sub(r'^https?://', '', url)
    # Replace any remaining special characters with underscores
    filename = re.sub(r'[^a-zA-Z0-9]', '_', url_without_protocol)
    # Add a ".txt" extension
    filename += '.txt'
    return filename

# Create the directory if it doesn't exist
save_dir = './text_us/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Download text from revenue's website
for url in urls:
    response = requests.get(url)
    if response.status_code == 200:
        # Extract and save the text content
        text_content = response.text
        
        # Remove HTML tags to get plain text (you can use a library like BeautifulSoup for more advanced parsing)
        # Here, we use a simple regex to remove HTML tags
        text_content = re.sub(r'<[^>]+>', '', text_content)
        
        # Convert the URL to a valid filename
        filename = os.path.join(save_dir, url_to_filename(url))
        
        # Save the plain text content to the file
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(text_content)
        print("Downloading text: " + filename)
    else:
        print(f"Failed to download {url}. Status code: {response.status_code}")
# Out:
# Downloading text: ./text_us/www_irs_gov_.txt
# Downloading text: ./text_us/www_irs_gov_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_newsroom.txt
# Downloading text: ./text_us/www_irs_gov_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_filing.txt
# Downloading text: ./text_us/www_irs_gov_how_to_file_your_taxes_step_by_step.txt
# Downloading text: ./text_us/www_irs_gov_businesses.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds.txt
# Downloading text: ./text_us/www_irs_gov_filing_individuals_how_to_file.txt
# Downloading text: ./text_us/www_irs_gov_filing_individuals_when_to_file.txt
# Downloading text: ./text_us/www_irs_gov_filing_where_to_file_tax_returns_addresses_listed_by_return_type.txt
# Downloading text: ./text_us/www_irs_gov_filing_individuals_update_my_information.txt
# Downloading text: ./text_us/www_irs_gov_individuals_get_transcript.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_apply_for_an_employer_identification_number_ein_online.txt
# Downloading text: ./text_us/www_irs_gov_filing_wheres_my_amended_return.txt
# Downloading text: ./text_us/www_irs_gov_identity_theft_fraud_scams_get_an_identity_protection_pin.txt
# Downloading text: ./text_us/www_irs_gov_filing_free_file_do_your_federal_taxes_for_free.txt
# Downloading text: ./text_us/www_irs_gov_payments.txt
# Downloading text: ./text_us/www_irs_gov_payments_direct_pay.txt
# Downloading text: ./text_us/www_irs_gov_payments_pay_your_taxes_by_debit_or_credit_card.txt
# Downloading text: ./text_us/www_irs_gov_payments_online_payment_agreement_application.txt
# Downloading text: ./text_us/www_irs_gov_payments_eftps_the_electronic_federal_tax_payment_system.txt
# Downloading text: ./text_us/www_irs_gov_payments_your_online_account.txt
# Downloading text: ./text_us/www_irs_gov_individuals_tax_withholding_estimator.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_estimated_taxes.txt
# Downloading text: ./text_us/www_irs_gov_payments_penalties.txt
# Downloading text: ./text_us/www_irs_gov_refunds.txt
# Downloading text: ./text_us/www_irs_gov_wheres_my_refund.txt
# Downloading text: ./text_us/www_irs_gov_refunds_what_to_expect_for_refunds_this_year.txt
# Downloading text: ./text_us/www_irs_gov_refunds_get_your_refund_faster_tell_irs_to_direct_deposit_your_refund_to_one_two_or_three_accounts.txt
# Downloading text: ./text_us/www_irs_gov_taxtopics_tc203.txt
# Downloading text: ./text_us/www_irs_gov_filing_file_an_amended_return.txt
# Downloading text: ./text_us/www_irs_gov_credits_and_deductions.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_for_individuals.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_businesses.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_eitc.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_individuals_child_tax_credit.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_clean_vehicle_and_energy_credits.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_how_much_is_my_standard_deduction.txt
# Downloading text: ./text_us/www_irs_gov_retirement_plans.txt
# Downloading text: ./text_us/www_irs_gov_forms_instructions.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_1040.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_i1040gi_pdf.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_w_9.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_4506_t.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_w_4.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_941.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_w_2.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_9465.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_1040x.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_2848.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_w_7.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_pcir230_pdf.txt
# Downloading text: ./text_us/www_irs_gov_help_ita.txt
# Downloading text: ./text_us/www_irs_gov_help_irs_document_upload_tool.txt
# Downloading text: ./text_us/www_irs_gov_filing_e_file_forms_1099_with_iris.txt
# Downloading text: ./text_us/www_irs_gov_help_irs2goapp.txt
# Downloading text: ./text_us/www_irs_gov_help_contact_your_local_irs_office.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_helps_taxpayers_by_providing_penalty_relief_on_nearly_5_million_2020_and_2021_tax_returns_restart_of_collection_notices_in_2024_marks_end_of_pandemic_related_pause.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_new_voluntary_disclosure_program_lets_employers_who_received_questionable_employee_retention_credits_pay_them_back_at_discounted_rate_interested_taxpayers_must_apply_by_march_22.txt
# Downloading text: ./text_us/www_irs_gov_about_irs_a_closer_look_at_the_irs_direct_file_pilot.txt
# Downloading text: ./text_us/www_irs_gov_about_irs_irs_inflation_reduction_act_strategic_operating_plan.txt
# Downloading text: ./text_us/www_irs_gov_credits_and_deductions_under_the_inflation_reduction_act_of_2022.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_updates_and_news_from_the_irs.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_operations_status_of_mission_critical_functions.txt
# Downloading text: ./text_us/www_irs_gov_about_irs.txt
# Downloading text: ./text_us/www_irs_gov_statistics_soi_tax_stats_irs_operations_and_budget.txt
# Downloading text: ./text_us/www_irs_gov_statistics.txt
# Downloading text: ./text_us/www_irs_gov_taxpayer_bill_of_rights.txt
# Downloading text: ./text_us/www_irs_gov_taxpayer_advocate.txt
# Downloading text: ./text_us/www_irs_gov_appeals.txt
# Downloading text: ./text_us/www_irs_gov_about_irs_protecting_taxpayer_civil_rights.txt
# Downloading text: ./text_us/www_irs_gov_privacy_disclosure_irs_freedom_of_information.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_irs_notice_or_letter.txt
# Downloading text: ./text_us/www_irs_gov_identity_theft_central.txt
# Downloading text: ./text_us/www_irs_gov_privacy_disclosure_report_phishing.txt
# Downloading text: ./text_us/www_irs_gov_compliance_criminal_investigation_tax_fraud_alerts.txt
# Downloading text: ./text_us/www_irs_gov_compliance_criminal_investigation.txt
# Downloading text: ./text_us/www_irs_gov_compliance_whistleblower_office.txt
# Downloading text: ./text_us/www_irs_gov_es.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant.txt
# Downloading text: ./text_us/www_irs_gov_ko.txt
# Downloading text: ./text_us/www_irs_gov_ru.txt
# Downloading text: ./text_us/www_irs_gov_vi.txt
# Downloading text: ./text_us/www_irs_gov_ht.txt
# Downloading text: ./text_us/www_irs_gov_help_languages.txt
# Downloading text: ./text_us/www_irs_gov_privacy_disclosure_irs_privacy_policy.txt
# Downloading text: ./text_us/www_irs_gov_es_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_ko_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_ru_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_vi_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_ht_help_telephone_assistance.txt
# Downloading text: ./text_us/www_irs_gov_help_tools.txt
# Downloading text: ./text_us/www_irs_gov_faqs.txt
# Downloading text: ./text_us/www_irs_gov_accessibility.txt
# Downloading text: ./text_us/www_irs_gov_help_contact_my_local_office_internationally.txt
# Downloading text: ./text_us/www_irs_gov_individuals_transcript_types_and_ways_to_order_them.txt
# Downloading text: ./text_us/www_irs_gov_individuals_get_transcript_faqs.txt
# Downloading text: ./text_us/www_irs_gov_taxtopics_tc161.txt
# Downloading text: ./text_us/www_irs_gov_faqs_irs_procedures_refund_inquiries_refund_inquiries_0.txt
# Downloading text: ./text_us/www_irs_gov_refunds_tax_season_refund_frequently_asked_questions.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_8379.txt
# Downloading text: ./text_us/www_irs_gov_faqs_irs_procedures_w_2_additional_incorrect_lost_non_receipt_omitted_w_2_additional_incorrect_lost_non_receipt_omitted.txt
# Downloading text: ./text_us/www_irs_gov_individuals_individual_taxpayer_identification_number.txt
# Downloading text: ./text_us/www_irs_gov_individuals_free_tax_return_preparation_for_qualifying_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_choosing_a_tax_professional.txt
# Downloading text: ./text_us/www_irs_gov_filing_e_file_options.txt
# Downloading text: ./text_us/www_irs_gov_individuals_deceased_person.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_filing_past_due_tax_returns.txt
# Downloading text: ./text_us/www_irs_gov_individuals_electronic_filing_pin_request.txt
# Downloading text: ./text_us/www_irs_gov_filing_where_to_file_paper_tax_returns_with_or_without_a_payment.txt
# Downloading text: ./text_us/www_irs_gov_taxtopics_tc418.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_do_i_need_to_file_a_tax_return.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_what_is_my_filing_status.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_are_my_social_security_or_railroad_retirement_tier_i_benefits_taxable.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_is_my_pension_or_annuity_payment_taxable.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_the_what_ifs_for_struggling_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_payments_offer_in_compromise.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_understanding_a_federal_tax_lien.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_levy.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p594_pdf.txt
# Downloading text: ./text_us/www_irs_gov_payments_penalty_relief.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_letter_5071c_or_6331c.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_letter_4883c_or_6330c.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp12_notice.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp504_notice.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp2000_notice.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp71a_notice.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp87a_notice.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_schedule_lep.txt
# Downloading text: ./text_us/www_irs_gov_help_ita_should_i_file_an_amended_return.txt
# Downloading text: ./text_us/www_irs_gov_filing_amended_return_frequently_asked_questions.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_taxpayer_guide_to_identity_theft.txt
# Downloading text: ./text_us/www_irs_gov_individuals_taxes_security_together.txt
# Downloading text: ./text_us/www_irs_gov_individuals_understanding_your_cp01_notice.txt
# Downloading text: ./text_us/www_irs_gov_identity_theft_fraud_scams_identity_and_tax_return_verification_service.txt
# Downloading text: ./text_us/www_irs_gov_individuals_how_do_you_report_suspected_tax_fraud_activity.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_make_a_complaint_about_a_tax_return_preparer.txt
# Downloading text: ./text_us/www_irs_gov_businesses_e_file_employment_tax_forms.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_using_a_form_94x_on_line_signature_pin_to_e_file_employment_tax_forms.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_employer_id_numbers.txt
# Downloading text: ./text_us/www_irs_gov_e_file_providers_e_file_form_2290.txt
# Downloading text: ./text_us/www_irs_gov_help_find_information_on_complex_tax_topics.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_8821.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_ptin_requirements_for_tax_return_preparers.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_form_56.txt
# Downloading text: ./text_us/www_irs_gov_faqs_irs_procedures_address_changes_address_changes.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_use_the_eitc_assistant.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_declaring_bankruptcy.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_relief_in_disaster_situations.txt
# Downloading text: ./text_us/www_irs_gov_faqs_irs_procedures_injured_spouse_injured_spouse.txt
# Downloading text: ./text_us/www_irs_gov_affordable_care_act.txt
# Downloading text: ./text_us/www_irs_gov_es_newsroom.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_newsroom.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_whats_hot.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_news_releases_for_current_month.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_multimedia_center.txt
# Downloading text: ./text_us/www_irs_gov_inflation_reduction_act_of_2022.txt
# Downloading text: ./text_us/www_irs_gov_tax_reform.txt
# Downloading text: ./text_us/www_irs_gov_taxpayer_first_act.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_scamsconsumer_alerts.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_the_tax_gap.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_fact_sheets.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_tax_tips.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_e_news_subscriptions.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_guidance.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_media_relations_office_contact_number.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_statements_and_announcements.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_the_qualified_alternative_fuel_vehicle_refueling_property_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_update_for_form_990_t_form_1120_pol_filers_with_upcoming_deadlines_e_file_unavailable_for_small_number_of_organizations_with_earlier_due_dates.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_and_treasury_reach_major_milestone_implementing_key_provisions_using_the_irs_energy_credits_online_elective_pay_and_transferability_tool.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_selects_12_new_irsac_members_for_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_and_irs_announce_that_businesses_do_not_have_to_report_certain_transactions_involving_digital_assets_until_regulations_are_issued.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_provides_initial_guidance_to_employers_setting_up_emergency_savings_accounts_for_their_employees.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_free_file_now_available_free_service_through_irsgov_available_for_millions_of_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_ramps_up_new_initiatives_using_inflation_reduction_act_funding_to_ensure_complex_partnerships_large_corporations_pay_taxes_owed_continues_to_close_millionaire_tax_debt_cases.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_webinar_on_2023_form_1099_k_rules_now_available_free_online_video_can_help_those_who_get_payments_through_payment_apps_and_online_marketplaces.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_national_taxpayer_advocate_delivers_annual_report_to_congress_focuses_on_taxpayer_impact_of_paper_processing_delays.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminder_jan_31_filing_deadline_for_employers_to_file_wage_statements_independent_contractor_forms.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_security_summit_partners_warn_of_surge_in_new_client_scams_aimed_at_tax_pros_as_2024_filing_season_approaches.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_2024_tax_filing_season_set_for_january_29_irs_continues_to_make_improvements_to_help_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_season_2024_irs_launches_tax_professional_awareness_week_focus_on_reminders_challenges_and_training_opportunities_for_experienced_and_new_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_more_time_for_dealers_and_sellers_of_clean_vehicles_to_submit_time_of_sale_reports.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_get_ready_irs_website_has_helpful_resources_for_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_request_public_comments_on_product_identification_number_requirement_to_claim_the_energy_efficient_home_improvement_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_provide_guidance_for_certain_clean_energy_producers_related_to_domestic_content_request_additional_comments_for_upcoming_regulations.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_updates_frequently_asked_questions_for_the_new_previously_owned_and_qualified_commercial_clean_vehicle_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_tennessee_taxpayers_impacted_by_storms_and_tornadoes_qualify_for_tax_relief_various_deadlines_postponed_to_june_17.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_opens_free_ira_and_chips_pre_filing_registration_tool_for_organizations_to_register_to_monetize_clean_energy_credits.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_the_tax_credit_for_the_production_of_clean_hydrogen.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminds_those_aged_73_and_older_to_make_required_withdrawals_from_iras_and_retirement_plans_by_dec_31_notes_changes_in_the_law_for_2023.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_issues_guidance_on_the_incremental_cost_for_the_commercial_clean_vehicle_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_transformation_work_continues_irs_expands_business_tax_account_access_to_s_corporations_partnerships_adds_ability_to_view_business_tax_transcripts.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminds_taxpayers_jan_16_due_date_for_final_2023_quarterly_estimated_tax_payments.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_clarifies_rules_for_corporate_alternative_minimum_tax.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_sustainable_aviation_fuel_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_issues_standard_mileage_rates_for_2024_mileage_rate_increases_to_67_cents_a_mile_up_1_point_5_cents_from_2023.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_for_the_advanced_manufacturing_production_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_plans_for_new_leadership_structure_adjustments_align_with_new_priorities_agency_transformation_work.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_free_dec_14_webinar_to_focus_on_tax_year_2023_form_1099_k_reporting_rules_designed_to_help_reporting_income_through_payment_apps_and_online_marketplaces.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_get_ready_to_file_in_2024_whats_new_and_what_to_consider.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_2024_flexible_spending_arrangement_contribution_limit_rises_by_150_dollars.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_independent_office_of_appeals_releases_fiscal_year_2024_priorities_focus_on_improving_taxpayer_service.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_honored_with_the_association_for_federal_enterprise_risk_managements_luminary_award.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_requests_applications_for_2024_etaac_membership.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_expands_work_on_aggressive_employee_retention_credit_claims_20000_disallowance_letters_being_mailed_more_action_and_voluntary_disclosure_program_coming.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_5_as_tax_season_approaches_irs_security_summit_partners_warn_taxpayers_tax_professionals_to_watch_out_for_emerging_scams_by_email_text_phone.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_provide_guidance_for_those_who_manufacture_new_clean_vehicles.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_4_summit_partners_urge_businesses_to_take_steps_to_prevent_data_loss_fraud.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_3_irs_identity_protection_pin_can_help_avoid_fraud_and_tax_related_identity_theft.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_supports_international_efforts_to_fight_fraud_during_charity_fraud_awareness_week.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_2_security_summit_reminds_tax_pros_about_importance_of_written_security_plans_and_data_breach_response_special_webinar_planned_for_nov_30.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_security_summit_partners_launch_2023_national_tax_security_awareness_week_focusing_on_holiday_scams_protecting_personal_information_as_tax_season_nears.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_savers_credit_can_help_low_and_moderate_income_taxpayers_to_save_more_in_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_delay_in_form_1099_k_reporting_threshold_for_third_party_platform_payments_in_2023_plans_for_a_threshold_of_5000_for_2024_to_phase_in_implementation.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_defining_energy_property.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_interest_rates_remain_the_same_for_the_first_quarter_of_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_security_summit_partners_announce_8th_annual_national_tax_security_awareness_week_begins_nov_27_focus_on_raising_awareness_among_taxpayers_tax_pros_on_security_tips_to_protect_against_identity.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminds_eligible_2020_and_2021_non_filers_to_claim_recovery_rebate_credit_before_time_runs_out.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_irs_propose_regulations_implementing_disallowance_of_deductions_for_certain_conservation_easement_contributions_by_partnerships_s_corporations.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_qualified_charitable_distributions_allow_eligible_ira_owners_up_to_100000_in_tax_free_gifts_to_charity.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_selects_rajiv_uppal_as_new_chief_information_officer_veteran_technology_executive_will_assist_with_ongoing_transformation_work.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_offers_free_nov_16_webinar_on_new_information_return_e_file_threshold_change_taking_effect_next_year.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_highlights_international_fraud_awareness_week_taxpayers_urged_to_protect_against_scams_schemes.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_updates_frequently_asked_questions_related_to_wrongful_incarceration_of_a_united_states_service_member.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_season_rapidly_approaching_get_ready_now_to_file_2023_federal_income_tax_returns_in_early_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_publishes_its_fiscal_year_2023_financial_report_receives_award_for_2022_report.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_provides_tax_inflation_adjustments_for_tax_year_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_advisory_council_issues_2023_annual_report.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_achieves_key_paperless_processing_initiative_goal_outlines_improvements_for_filing_season_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_clean_vehicle_sellers_and_dealers_should_register_with_energy_credits_online_register_by_dec_1_2023_to_ensure_jan_1_availability.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_avoid_a_surprise_next_year_review_tax_withholding_now_before_time_runs_out.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_digital_asset_public_hearing_rescheduled_for_nov_13.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_401k_limit_increases_to_23000_for_2024_ira_limit_rises_to_7000.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_opens_free_energy_credit_online_tool_for_sellers_of_clean_vehicles_to_register_for_time_of_sale_reporting_and_dealer_advance_payments_for_the_clean_vehicle_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_free_irs_webinar_shares_latest_details_on_the_employee_retention_credit_including_options_for_withdrawing_or_correcting_previously_filed_claims_amid_aggressive_marketing.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_and_security_summit_offer_online_safety_tips_during_national_cybersecurity_awareness_month.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_extends_popular_flexibilities_set_to_expire_electronic_signatures_and_encrypted_email_enhance_the_taxpayer_experience.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_encourages_employers_to_electronically_file_payroll_tax_returns.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_2024_ptin_renewal_period_underway_for_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_beware_of_fake_charities_check_before_donating.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_volunteers_needed_across_the_country_for_free_tax_services.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_launches_new_initiatives_using_inflation_reduction_act_funding_to_ensure_large_corporations_pay_taxes_owed_continues_to_improve_service_and_modernize_technology_with_launch_of_business_tax_account.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_withdrawal_process_for_employee_retention_credit_claims_special_initiative_aimed_at_helping_businesses_concerned_about_an_ineligible_claim_amid_aggressive_marketing_scams.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_advances_innovative_direct_file_project_for_2024_tax_season_free_irs_run_pilot_option_projected_to_be_available_for_eligible_taxpayers_in_13_states.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_2024_tax_counseling_for_the_elderly_and_volunteer_income_tax_assistance_program_grants.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_most_popular_seminars_at_the_2023_irs_nationwide_tax_forums_now_available_online.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_for_california_storm_victims_irs_postpones_tax_filing_and_tax_payment_deadline_to_nov_16.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_the_terrorist_attacks_in_israel_qualify_for_tax_relief_oct_16_filing_deadline_other_dates_postponed_to_oct_7_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_updates_tax_gap_projections_for_2020_2021_projected_annual_gap_rises_to_688_billion.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_issues_guidance_for_the_transfer_of_clean_vehicle_credits_and_updates_frequently_asked_questions.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_warns_taxpayers_of_improper_art_donation_deduction_promotions_highlights_common_red_flags.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_seawater_intrusion_in_parts_of_louisiana_qualify_for_tax_relief_various_deadlines_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_oct_16_tax_filing_extension_deadline_nears_for_millions_of_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_delivers_new_capabilities_to_tax_pro_account_latest_expansion_part_of_effort_to_improve_technology_tools_to_help_tax_professionals_serve_clients.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_provides_guidance_on_employer_leave_based_donation_programs_that_aid_victims_of_the_wildfires_in_hawaii.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_builders_of_qualified_new_energy_efficient_homes_may_qualify_for_an_expanded_tax_credit_under_section_45l.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_extends_relief_to_farmers_and_ranchers_in_49_states_other_areas_impacted_by_drought_more_time_to_replace_livestock.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_expands_use_of_chatbots_to_help_answer_questions_on_key_notices_expands_on_technology_thats_served_13_million_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_hurricane_lee_in_maine_and_massachusetts_qualify_for_tax_relief_various_deadlines_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_to_establish_special_pass_through_organization_to_help_with_high_income_compliance_efforts_new_workgroup_to_blend_current_employees_and_new_hires_to_focus_on_complex_partnerships_other_key_areas.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_electronic_tax_administration_advisory_committee_select_8_new_members.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminder_to_storm_victims_in_3_states_file_and_pay_by_oct_16_most_of_california_parts_of_alabama_and_georgia_affected.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_requests_feedback_on_preview_of_proposed_changes_to_form_6765_credit_for_increasing_research_activities.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_looks_to_hire_3700_employees_nationwide_to_help_expand_compliance_for_large_corporations_and_complex_partnerships_experienced_accountants_encouraged_to_apply_for_revenue_agent_positions.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_requests_comments_on_expanding_tax_certainty_and_issue_resolution_programs_for_business_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_red_flags_for_employee_retention_credit_claims_irs_reminds_businesses_to_watch_out_for_warning_signs_of_aggressive_promotion_that_can_mislead_people_into_making_improper_erc_claims.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_to_protect_taxpayers_from_scams_irs_orders_immediate_stop_to_new_employee_retention_credit_processing_amid_surge_of_questionable_claims_concerns_from_tax_pros.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_georgia_taxpayers_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_clarifies_rules_for_new_corporate_alternative_minimum_tax.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_sweeping_effort_to_restore_fairness_to_tax_system_with_inflation_reduction_act_funding_new_compliance_efforts.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminds_gig_workers_self_employed_and_others_of_sept_15_third_quarter_estimated_tax_payment_deadline.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_accepting_applicants_for_the_2024_compliance_assurance_process.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_south_carolina_taxpayers_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_issues_a_frequently_asked_question_for_pass_through_entities_to_report_negative_amounts_electronically_to_the_irs_on_part_ii_of_schedules_k_2_and_k_3.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_september_is_national_preparedness_month_irs_reminds_taxpayers_to_prepare_for_natural_disasters.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_reminder_make_sure_to_understand_recent_changes_when_buying_a_clean_vehicle.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_those_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_issues_guidance_on_state_tax_payments.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_businesses_must_electronically_file_form_8300_report_of_cash_payments_over_10000_beginning_jan_1_2024.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_on_prevailing_wage_and_apprenticeship_requirements_for_increased_energy_credit_or_deduction_amounts.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_announces_administrative_transition_period_for_new_roth_catch_up_requirement_catch_up_contributions_still_permitted_after_2023.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_interest_rates_increase_for_the_fourth_quarter_2023.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_on_reporting_by_brokers_for_sales_or_exchanges_of_digital_assets_new_steps_designed_to_end_confusion_help_taxpayers_aid_high_income_compliance_work.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_reminder_to_employers_and_employees_educational_assistance_programs_can_be_used_to_help_pay_workers_student_loans_free_irs_webinar_will_offer_details.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_hawaii_wildfire_victims_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_new_school_year_reminder_to_educators_maximum_educator_expense_deduction_is_300_in_2023.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_encourages_truckers_to_e_file_by_august_31_tax_payment_deadline.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_inflation_reduction_act_1_year_report_card_irs_delivers_dramatically_improved_2023_filing_season_service_modernizes_technology_pursues_high_income_individuals_evading_taxes.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_security_summit_irs_reminds_tax_pros_to_plan_protect_defend_against_identity_theft_special_summer_series_concludes_with_important_reminders.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_news_release_and_fact_sheet_archive.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p5382_pdf.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_prior_p5382__2020_pdf.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_irs_update_on_audits.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_tax_reform_resources.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_commissioners_comments_statements_and_remarks.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_filing_season_statistics_by_year.txt
# Downloading text: ./text_us/www_irs_gov_compliance_criminal_investigation_criminal_investigation_press_releases.txt
# Downloading text: ./text_us/www_irs_gov_a_closer_look.txt
# Downloading text: ./text_us/www_irs_gov_coronavirus_tax_relief_and_economic_impact_payments.txt
# Downloading text: ./text_us/www_irs_gov_outreach_connection.txt
# Downloading text: ./text_us/www_irs_gov_es_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_ko_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_ru_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_vi_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_ht_charities_and_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_exempt_organization_types.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_life_cycle_of_an_exempt_organization.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_annual_filing_and_forms.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_charitable_contributions.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_tax_exempt_organization_search.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_calendar_of_events.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_governmental_liaisons.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_elective_pay_and_transferability.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p5884_pdf.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_applying_for_tax_exempt_status.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_charitable_organizations_automatic_revocation_how_to_have_your_tax_exempt_status_reinstated.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_contributors_tax_information_on_donated_property.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_charitable_organizations.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_churches_religious_organizations.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_charitable_organizations_private_foundations.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_political_organizations.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_other_nonprofits.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_educational_resources_and_guidance_for_exempt_organizations.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_tax_exempt_and_government_entities_issue_snapshots.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_tax_exempt_and_government_entities_annual_priority_program_letters.txt
# Downloading text: ./text_us/www_irs_gov_coronavirus_coronavirus_tax_relief_for_businesses_and_tax_exempt_entities.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_tax_exempt_government_entities_compliance_program_and_priorities.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_current_edition_of_exempt_organizations_update.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_charities_non_profits_a_z_site_index.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_contact_irs_exempt_organizations.txt
# Downloading text: ./text_us/www_irs_gov_charities_non_profits_subscribe_to_exempt_organization_update.txt
# Downloading text: ./text_us/www_irs_gov_es_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_ko_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_ru_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_vi_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_ht_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_enrolled_agents.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_annual_filing_season_program.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_enrolled_retirement_plan_agent_program.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_certified_professional_employer_organization.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_enrolled_actuaries.txt
# Downloading text: ./text_us/www_irs_gov_e_file_providers_efile_for_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_e_file_providers_modernized_e_file_program_information.txt
# Downloading text: ./text_us/www_irs_gov_e_services.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_tax_pro_account.txt
# Downloading text: ./text_us/www_irs_gov_submit_power_of_attorney_and_tax_information_authorizations.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_serve_your_clients.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_stay_compliant.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_continuing_education_for_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_identity_theft_fraud_scams_identity_theft_information_for_tax_professionals.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_when_to_expect_your_refund_if_you_claimed_the_earned_income_tax_credit_or_additional_child_tax_credit.txt
# Downloading text: ./text_us/www_irs_gov_filing_statutes_of_limitations_for_assessing_collecting_and_refunding_tax.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_employee_retention_credit_eligibility_checklist_help_understanding_this_complex_credit.txt
# Downloading text: ./text_us/www_irs_gov_newsroom_2023_irs_nationwide_tax_forums_to_be_held_in_five_cities.txt
# Downloading text: ./text_us/www_irs_gov_taxtopics_tc153.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_tax_pro_news_and_resources.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_practitioner_priority_service_r.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_contact_the_return_preparer_program.txt
# Downloading text: ./text_us/www_irs_gov_tax_professionals_office_of_professional_responsibility_and_circular_230.txt
# Downloading text: ./text_us/www_irs_gov_e_file_providers_become_an_authorized_e_file_provider.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p1345_pdf.txt
# Downloading text: ./text_us/www_irs_gov_filing_e_file_information_returns.txt
# Downloading text: ./text_us/www_irs_gov_es_filing.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_filing.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_filing.txt
# Downloading text: ./text_us/www_irs_gov_ko_filing.txt
# Downloading text: ./text_us/www_irs_gov_ru_filing.txt
# Downloading text: ./text_us/www_irs_gov_vi_filing.txt
# Downloading text: ./text_us/www_irs_gov_ht_filing.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_resources_for_federal_state_and_local_governments.txt
# Downloading text: ./text_us/www_irs_gov_individuals_check_if_you_need_to_file_a_tax_return.txt
# Downloading text: ./text_us/www_irs_gov_individuals_managing_your_taxes_after_a_life_event.txt
# Downloading text: ./text_us/www_irs_gov_individuals_students.txt
# Downloading text: ./text_us/www_irs_gov_individuals_employees.txt
# Downloading text: ./text_us/www_irs_gov_individuals_parents.txt
# Downloading text: ./text_us/www_irs_gov_individuals_military.txt
# Downloading text: ./text_us/www_irs_gov_individuals_seniors_retirees.txt
# Downloading text: ./text_us/www_irs_gov_individuals_gather_your_documents.txt
# Downloading text: ./text_us/www_irs_gov_payments_pay_taxes_on_time.txt
# Downloading text: ./text_us/www_irs_gov_individuals_be_ready_to_file_taxes_next_year.txt
# Downloading text: ./text_us/www_irs_gov_credits_deductions_refundable_tax_credits.txt
# Downloading text: ./text_us/www_irs_gov_publications_p17.txt
# Downloading text: ./text_us/www_irs_gov_es_businesses.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_businesses.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_businesses.txt
# Downloading text: ./text_us/www_irs_gov_ko_businesses.txt
# Downloading text: ./text_us/www_irs_gov_ru_businesses.txt
# Downloading text: ./text_us/www_irs_gov_vi_businesses.txt
# Downloading text: ./text_us/www_irs_gov_ht_businesses.txt
# Downloading text: ./text_us/www_irs_gov_businesses_business_tax_account.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed.txt
# Downloading text: ./text_us/www_irs_gov_businesses_large_business_and_international_tax_center.txt
# Downloading text: ./text_us/www_irs_gov_corporations.txt
# Downloading text: ./text_us/www_irs_gov_businesses_partnerships.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_employment_taxes.txt
# Downloading text: ./text_us/www_irs_gov_businesses_corporations_foreign_account_tax_compliance_act_fatca.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_business_tax_credits.txt
# Downloading text: ./text_us/www_irs_gov_publications_p535.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_excise_tax.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_estate_and_gift_taxes.txt
# Downloading text: ./text_us/www_irs_gov_businesses_online_ordering_for_information_returns_and_employer_returns.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_starting_a_business.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_operating_a_business.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_closing_a_business.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_sole_proprietorships.txt
# Downloading text: ./text_us/www_irs_gov_businesses_international_business.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_forming_a_corporation.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_s_corporations.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_limited_liability_company_llc.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_disaster_assistance_and_emergency_relief_for_individuals_and_businesses.txt
# Downloading text: ./text_us/www_irs_gov_es_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_zh_hans_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_zh_hant_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_ko_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_ru_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_vi_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_ht_individuals_international_taxpayers.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_individuals.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_taxpayers_foreign_persons.txt
# Downloading text: ./text_us/www_irs_gov_businesses_dispute_resolution.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_taxpayers_individuals_living_or_working_in_us_possessions.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_taxpayers_us_citizens_and_resident_aliens_abroad.txt
# Downloading text: ./text_us/www_irs_gov_individuals_international_taxpayers_tax_treaties.txt
# Downloading text: ./text_us/www_irs_gov_businesses_corporations_transfer_pricing_examination_process.txt
# Downloading text: ./text_us/www_irs_gov_businesses_international_businesses_us_withholding_agent_program.txt
# Downloading text: ./text_us/www_irs_gov_businesses_international_businesses_country_by_country_reporting.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_employee_classifications.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_employment_taxes.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_human_resources_and_benefits.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_return_filing.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_stay_compliant.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_answers_to_common_questions.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_information_returns.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_a_guide_to_information_returns.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_information_return_reporting.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_taxpayer_identification_matching_tin_tools.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_tax_withholding_for_government_workers.txt
# Downloading text: ./text_us/www_irs_gov_forms_pubs_about_publication_15_t.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_state_and_local_government_employees_social_security_and_medicare_coverage.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_election_workers_reporting_and_withholding.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_employer_and_payroll_information.txt
# Downloading text: ./text_us/www_irs_gov_businesses_small_businesses_self_employed_employee_benefits.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_de_minimis_fringe_benefits.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_group_term_life_insurance.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_federal_state_local_employment_tax_fslet_customer_services.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_federal_state_local_governments_news_for_federal_state_and_local_governments.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_webinars_for_tax_exempt_government_entities.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_government_issues.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_member_issues.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_gaming_and_casinos.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_employment_taxes.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_published_guidance_for_tribes.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_communication_outreach_education.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_news.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_contacts.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_internal_revenue_code_sections.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_private_letter_rulings.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_general_welfare_guidance.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_frequently_asked_questions_and_answers_for_indian_tribal_governments.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_status_of_tribes_taxable_vs_nontaxable_vs_not_subject_to_tax.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_tax_examinations.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p5343_pdf.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p5424_pdf.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_volunteer_tax_assistance_resources_for_indian_country.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_gaming_withholdings.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_gaming_revenue_distributions_including_per_capita_payments_and_igra.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_title_31_anti_money_laundering.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p3908_pdf.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_irs_electronic_filing_and_e_services.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_employment_taxes_for_tribes.txt
# Downloading text: ./text_us/www_irs_gov_pub_irs_pdf_p4268_pdf.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_reporting_abusive_schemes_and_their_promoters.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_consultation_procedures.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_indian_tribal_governments_news.txt
# Downloading text: ./text_us/www_irs_gov_government_entities_indian_tribal_governments_subscribe_to_indian_tribal_governments_news.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_tax_credit_and_direct_pay_bonds.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_forms_and_filing_requirements_for_tax_exempt_bonds.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_post_issuance_compliance.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_published_guidance.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_reference_materials.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_news.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_contacts.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_tax_exempt_bonds_community_updates.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_teb_voluntary_closing_agreement_program.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_subscription_to_tax_exempt_bond_community_news.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_teb_post_issuance_compliance_some_basic_concepts.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_irs_complaint_or_referral_process_tax_exempt_bonds.txt
# Downloading text: ./text_us/www_irs_gov_tax_exempt_bonds_tax_exempt_bonds_faqs_regarding_reissuance.txt

# %% [markdown]
# ## Clean Text Data

# %%
# Path to the directory containing your text files
input_path = './text_us/'
output_path = './data_us/'

# Iterate over each file in the directory
for filename in os.listdir(input_path):
    if filename.endswith(".txt"):  # or .html, .js, etc, depending on your file type
        file_path = os.path.join(input_path, filename)

        # Read the content of the file
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

        # Remove tabs and newline characters while preserving spaces
        modified_content = content

        file_path = os.path.join(output_path, filename)
        # Write the modified content back to the file
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(modified_content)

        print("cleaned: " + file_path)
# Out:
# cleaned: ./data_us/www_irs_gov_.txt
# cleaned: ./data_us/www_irs_gov_about_irs.txt
# cleaned: ./data_us/www_irs_gov_about_irs_a_closer_look_at_the_irs_direct_file_pilot.txt
# cleaned: ./data_us/www_irs_gov_about_irs_irs_inflation_reduction_act_strategic_operating_plan.txt
# cleaned: ./data_us/www_irs_gov_about_irs_protecting_taxpayer_civil_rights.txt
# cleaned: ./data_us/www_irs_gov_accessibility.txt
# cleaned: ./data_us/www_irs_gov_affordable_care_act.txt
# cleaned: ./data_us/www_irs_gov_appeals.txt
# cleaned: ./data_us/www_irs_gov_a_closer_look.txt
# cleaned: ./data_us/www_irs_gov_businesses.txt
# cleaned: ./data_us/www_irs_gov_businesses_business_tax_account.txt
# cleaned: ./data_us/www_irs_gov_businesses_corporations_foreign_account_tax_compliance_act_fatca.txt
# cleaned: ./data_us/www_irs_gov_businesses_corporations_transfer_pricing_examination_process.txt
# cleaned: ./data_us/www_irs_gov_businesses_dispute_resolution.txt
# cleaned: ./data_us/www_irs_gov_businesses_e_file_employment_tax_forms.txt
# cleaned: ./data_us/www_irs_gov_businesses_international_business.txt
# cleaned: ./data_us/www_irs_gov_businesses_international_businesses_country_by_country_reporting.txt
# cleaned: ./data_us/www_irs_gov_businesses_international_businesses_us_withholding_agent_program.txt
# cleaned: ./data_us/www_irs_gov_businesses_large_business_and_international_tax_center.txt
# cleaned: ./data_us/www_irs_gov_businesses_online_ordering_for_information_returns_and_employer_returns.txt
# cleaned: ./data_us/www_irs_gov_businesses_partnerships.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_apply_for_an_employer_identification_number_ein_online.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_a_guide_to_information_returns.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_business_tax_credits.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_closing_a_business.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_declaring_bankruptcy.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_disaster_assistance_and_emergency_relief_for_individuals_and_businesses.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_employee_benefits.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_employer_id_numbers.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_employment_taxes.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_estate_and_gift_taxes.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_estimated_taxes.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_excise_tax.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_filing_past_due_tax_returns.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_forming_a_corporation.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_information_return_reporting.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_levy.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_limited_liability_company_llc.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_operating_a_business.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_sole_proprietorships.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_starting_a_business.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_s_corporations.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_understanding_a_federal_tax_lien.txt
# cleaned: ./data_us/www_irs_gov_businesses_small_businesses_self_employed_using_a_form_94x_on_line_signature_pin_to_e_file_employment_tax_forms.txt
# cleaned: ./data_us/www_irs_gov_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_annual_filing_and_forms.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_applying_for_tax_exempt_status.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_calendar_of_events.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_charitable_contributions.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_charitable_organizations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_charitable_organizations_automatic_revocation_how_to_have_your_tax_exempt_status_reinstated.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_charitable_organizations_private_foundations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_charities_non_profits_a_z_site_index.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_churches_religious_organizations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_contact_irs_exempt_organizations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_contributors_tax_information_on_donated_property.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_current_edition_of_exempt_organizations_update.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_educational_resources_and_guidance_for_exempt_organizations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_exempt_organization_types.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_life_cycle_of_an_exempt_organization.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_other_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_political_organizations.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_subscribe_to_exempt_organization_update.txt
# cleaned: ./data_us/www_irs_gov_charities_non_profits_tax_exempt_organization_search.txt
# cleaned: ./data_us/www_irs_gov_compliance_criminal_investigation.txt
# cleaned: ./data_us/www_irs_gov_compliance_criminal_investigation_criminal_investigation_press_releases.txt
# cleaned: ./data_us/www_irs_gov_compliance_criminal_investigation_tax_fraud_alerts.txt
# cleaned: ./data_us/www_irs_gov_compliance_whistleblower_office.txt
# cleaned: ./data_us/www_irs_gov_coronavirus_coronavirus_tax_relief_for_businesses_and_tax_exempt_entities.txt
# cleaned: ./data_us/www_irs_gov_coronavirus_tax_relief_and_economic_impact_payments.txt
# cleaned: ./data_us/www_irs_gov_corporations.txt
# cleaned: ./data_us/www_irs_gov_credits_and_deductions.txt
# cleaned: ./data_us/www_irs_gov_credits_and_deductions_under_the_inflation_reduction_act_of_2022.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_businesses.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_clean_vehicle_and_energy_credits.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_elective_pay_and_transferability.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_for_individuals.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_individuals_child_tax_credit.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_eitc.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_use_the_eitc_assistant.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_individuals_earned_income_tax_credit_when_to_expect_your_refund_if_you_claimed_the_earned_income_tax_credit_or_additional_child_tax_credit.txt
# cleaned: ./data_us/www_irs_gov_credits_deductions_refundable_tax_credits.txt
# cleaned: ./data_us/www_irs_gov_es.txt
# cleaned: ./data_us/www_irs_gov_es_businesses.txt
# cleaned: ./data_us/www_irs_gov_es_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_es_filing.txt
# cleaned: ./data_us/www_irs_gov_es_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_es_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_es_newsroom.txt
# cleaned: ./data_us/www_irs_gov_es_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_e_file_providers_become_an_authorized_e_file_provider.txt
# cleaned: ./data_us/www_irs_gov_e_file_providers_efile_for_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_e_file_providers_e_file_form_2290.txt
# cleaned: ./data_us/www_irs_gov_e_file_providers_modernized_e_file_program_information.txt
# cleaned: ./data_us/www_irs_gov_e_services.txt
# cleaned: ./data_us/www_irs_gov_faqs.txt
# cleaned: ./data_us/www_irs_gov_faqs_irs_procedures_address_changes_address_changes.txt
# cleaned: ./data_us/www_irs_gov_faqs_irs_procedures_injured_spouse_injured_spouse.txt
# cleaned: ./data_us/www_irs_gov_faqs_irs_procedures_refund_inquiries_refund_inquiries_0.txt
# cleaned: ./data_us/www_irs_gov_faqs_irs_procedures_w_2_additional_incorrect_lost_non_receipt_omitted_w_2_additional_incorrect_lost_non_receipt_omitted.txt
# cleaned: ./data_us/www_irs_gov_filing.txt
# cleaned: ./data_us/www_irs_gov_filing_amended_return_frequently_asked_questions.txt
# cleaned: ./data_us/www_irs_gov_filing_e_file_forms_1099_with_iris.txt
# cleaned: ./data_us/www_irs_gov_filing_e_file_information_returns.txt
# cleaned: ./data_us/www_irs_gov_filing_e_file_options.txt
# cleaned: ./data_us/www_irs_gov_filing_file_an_amended_return.txt
# cleaned: ./data_us/www_irs_gov_filing_free_file_do_your_federal_taxes_for_free.txt
# cleaned: ./data_us/www_irs_gov_filing_individuals_how_to_file.txt
# cleaned: ./data_us/www_irs_gov_filing_individuals_update_my_information.txt
# cleaned: ./data_us/www_irs_gov_filing_individuals_when_to_file.txt
# cleaned: ./data_us/www_irs_gov_filing_statutes_of_limitations_for_assessing_collecting_and_refunding_tax.txt
# cleaned: ./data_us/www_irs_gov_filing_wheres_my_amended_return.txt
# cleaned: ./data_us/www_irs_gov_filing_where_to_file_paper_tax_returns_with_or_without_a_payment.txt
# cleaned: ./data_us/www_irs_gov_filing_where_to_file_tax_returns_addresses_listed_by_return_type.txt
# cleaned: ./data_us/www_irs_gov_forms_instructions.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_1040.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_1040x.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_2848.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_4506_t.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_56.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_8379.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_8821.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_941.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_9465.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_w_2.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_w_4.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_w_7.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_form_w_9.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_publication_15_t.txt
# cleaned: ./data_us/www_irs_gov_forms_pubs_about_schedule_lep.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_answers_to_common_questions.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_de_minimis_fringe_benefits.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_election_workers_reporting_and_withholding.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_employee_classifications.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_employer_and_payroll_information.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_employment_taxes.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_federal_state_local_employment_tax_fslet_customer_services.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_group_term_life_insurance.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_human_resources_and_benefits.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_information_returns.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_news_for_federal_state_and_local_governments.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_resources_for_federal_state_and_local_governments.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_return_filing.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_state_and_local_government_employees_social_security_and_medicare_coverage.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_stay_compliant.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_taxpayer_identification_matching_tin_tools.txt
# cleaned: ./data_us/www_irs_gov_government_entities_federal_state_local_governments_tax_withholding_for_government_workers.txt
# cleaned: ./data_us/www_irs_gov_government_entities_governmental_liaisons.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_communication_outreach_education.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_consultation_procedures.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_contacts.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_employment_taxes.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_employment_taxes_for_tribes.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_gaming_revenue_distributions_including_per_capita_payments_and_igra.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_gaming_withholdings.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_status_of_tribes_taxable_vs_nontaxable_vs_not_subject_to_tax.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_faqs_for_indian_tribal_governments_regarding_title_31_anti_money_laundering.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_frequently_asked_questions_and_answers_for_indian_tribal_governments.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_gaming_and_casinos.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_indian_tribal_governments_news.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_internal_revenue_code_sections.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_irs_electronic_filing_and_e_services.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_news.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_private_letter_rulings.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_published_guidance_for_tribes.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_reporting_abusive_schemes_and_their_promoters.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_subscribe_to_indian_tribal_governments_news.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_general_welfare_guidance.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_government_issues.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_member_issues.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_tribal_tax_examinations.txt
# cleaned: ./data_us/www_irs_gov_government_entities_indian_tribal_governments_volunteer_tax_assistance_resources_for_indian_country.txt
# cleaned: ./data_us/www_irs_gov_government_entities_tax_exempt_and_government_entities_annual_priority_program_letters.txt
# cleaned: ./data_us/www_irs_gov_government_entities_tax_exempt_and_government_entities_issue_snapshots.txt
# cleaned: ./data_us/www_irs_gov_government_entities_tax_exempt_government_entities_compliance_program_and_priorities.txt
# cleaned: ./data_us/www_irs_gov_government_entities_webinars_for_tax_exempt_government_entities.txt
# cleaned: ./data_us/www_irs_gov_help_contact_my_local_office_internationally.txt
# cleaned: ./data_us/www_irs_gov_help_contact_your_local_irs_office.txt
# cleaned: ./data_us/www_irs_gov_help_find_information_on_complex_tax_topics.txt
# cleaned: ./data_us/www_irs_gov_help_irs2goapp.txt
# cleaned: ./data_us/www_irs_gov_help_irs_document_upload_tool.txt
# cleaned: ./data_us/www_irs_gov_help_ita.txt
# cleaned: ./data_us/www_irs_gov_help_ita_are_my_social_security_or_railroad_retirement_tier_i_benefits_taxable.txt
# cleaned: ./data_us/www_irs_gov_help_ita_do_i_need_to_file_a_tax_return.txt
# cleaned: ./data_us/www_irs_gov_help_ita_how_much_is_my_standard_deduction.txt
# cleaned: ./data_us/www_irs_gov_help_ita_is_my_pension_or_annuity_payment_taxable.txt
# cleaned: ./data_us/www_irs_gov_help_ita_should_i_file_an_amended_return.txt
# cleaned: ./data_us/www_irs_gov_help_ita_what_is_my_filing_status.txt
# cleaned: ./data_us/www_irs_gov_help_languages.txt
# cleaned: ./data_us/www_irs_gov_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_help_tools.txt
# cleaned: ./data_us/www_irs_gov_how_to_file_your_taxes_step_by_step.txt
# cleaned: ./data_us/www_irs_gov_ht.txt
# cleaned: ./data_us/www_irs_gov_ht_businesses.txt
# cleaned: ./data_us/www_irs_gov_ht_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_ht_filing.txt
# cleaned: ./data_us/www_irs_gov_ht_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_ht_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_ht_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_identity_theft_central.txt
# cleaned: ./data_us/www_irs_gov_identity_theft_fraud_scams_get_an_identity_protection_pin.txt
# cleaned: ./data_us/www_irs_gov_identity_theft_fraud_scams_identity_and_tax_return_verification_service.txt
# cleaned: ./data_us/www_irs_gov_identity_theft_fraud_scams_identity_theft_information_for_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_individuals_be_ready_to_file_taxes_next_year.txt
# cleaned: ./data_us/www_irs_gov_individuals_check_if_you_need_to_file_a_tax_return.txt
# cleaned: ./data_us/www_irs_gov_individuals_deceased_person.txt
# cleaned: ./data_us/www_irs_gov_individuals_electronic_filing_pin_request.txt
# cleaned: ./data_us/www_irs_gov_individuals_employees.txt
# cleaned: ./data_us/www_irs_gov_individuals_free_tax_return_preparation_for_qualifying_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_individuals_gather_your_documents.txt
# cleaned: ./data_us/www_irs_gov_individuals_get_transcript.txt
# cleaned: ./data_us/www_irs_gov_individuals_get_transcript_faqs.txt
# cleaned: ./data_us/www_irs_gov_individuals_how_do_you_report_suspected_tax_fraud_activity.txt
# cleaned: ./data_us/www_irs_gov_individuals_individual_taxpayer_identification_number.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_individuals.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_taxpayers_foreign_persons.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_taxpayers_individuals_living_or_working_in_us_possessions.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_taxpayers_tax_treaties.txt
# cleaned: ./data_us/www_irs_gov_individuals_international_taxpayers_us_citizens_and_resident_aliens_abroad.txt
# cleaned: ./data_us/www_irs_gov_individuals_managing_your_taxes_after_a_life_event.txt
# cleaned: ./data_us/www_irs_gov_individuals_military.txt
# cleaned: ./data_us/www_irs_gov_individuals_parents.txt
# cleaned: ./data_us/www_irs_gov_individuals_seniors_retirees.txt
# cleaned: ./data_us/www_irs_gov_individuals_students.txt
# cleaned: ./data_us/www_irs_gov_individuals_taxes_security_together.txt
# cleaned: ./data_us/www_irs_gov_individuals_tax_withholding_estimator.txt
# cleaned: ./data_us/www_irs_gov_individuals_transcript_types_and_ways_to_order_them.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp01_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp12_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp2000_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp504_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp71a_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_cp87a_notice.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_irs_notice_or_letter.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_letter_4883c_or_6330c.txt
# cleaned: ./data_us/www_irs_gov_individuals_understanding_your_letter_5071c_or_6331c.txt
# cleaned: ./data_us/www_irs_gov_inflation_reduction_act_of_2022.txt
# cleaned: ./data_us/www_irs_gov_ko.txt
# cleaned: ./data_us/www_irs_gov_ko_businesses.txt
# cleaned: ./data_us/www_irs_gov_ko_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_ko_filing.txt
# cleaned: ./data_us/www_irs_gov_ko_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_ko_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_ko_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_newsroom.txt
# cleaned: ./data_us/www_irs_gov_newsroom_2023_irs_nationwide_tax_forums_to_be_held_in_five_cities.txt
# cleaned: ./data_us/www_irs_gov_newsroom_2024_tax_filing_season_set_for_january_29_irs_continues_to_make_improvements_to_help_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_401k_limit_increases_to_23000_for_2024_ira_limit_rises_to_7000.txt
# cleaned: ./data_us/www_irs_gov_newsroom_avoid_a_surprise_next_year_review_tax_withholding_now_before_time_runs_out.txt
# cleaned: ./data_us/www_irs_gov_newsroom_businesses_must_electronically_file_form_8300_report_of_cash_payments_over_10000_beginning_jan_1_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_clean_vehicle_sellers_and_dealers_should_register_with_energy_credits_online_register_by_dec_1_2023_to_ensure_jan_1_availability.txt
# cleaned: ./data_us/www_irs_gov_newsroom_commissioners_comments_statements_and_remarks.txt
# cleaned: ./data_us/www_irs_gov_newsroom_digital_asset_public_hearing_rescheduled_for_nov_13.txt
# cleaned: ./data_us/www_irs_gov_newsroom_employee_retention_credit_eligibility_checklist_help_understanding_this_complex_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_e_news_subscriptions.txt
# cleaned: ./data_us/www_irs_gov_newsroom_fact_sheets.txt
# cleaned: ./data_us/www_irs_gov_newsroom_filing_season_statistics_by_year.txt
# cleaned: ./data_us/www_irs_gov_newsroom_for_california_storm_victims_irs_postpones_tax_filing_and_tax_payment_deadline_to_nov_16.txt
# cleaned: ./data_us/www_irs_gov_newsroom_free_irs_webinar_shares_latest_details_on_the_employee_retention_credit_including_options_for_withdrawing_or_correcting_previously_filed_claims_amid_aggressive_marketing.txt
# cleaned: ./data_us/www_irs_gov_newsroom_get_ready_irs_website_has_helpful_resources_for_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_get_ready_to_file_in_2024_whats_new_and_what_to_consider.txt
# cleaned: ./data_us/www_irs_gov_newsroom_inflation_reduction_act_1_year_report_card_irs_delivers_dramatically_improved_2023_filing_season_service_modernizes_technology_pursues_high_income_individuals_evading_taxes.txt
# cleaned: ./data_us/www_irs_gov_newsroom_interest_rates_increase_for_the_fourth_quarter_2023.txt
# cleaned: ./data_us/www_irs_gov_newsroom_interest_rates_remain_the_same_for_the_first_quarter_of_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_2024_flexible_spending_arrangement_contribution_limit_rises_by_150_dollars.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_2024_ptin_renewal_period_underway_for_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_accepting_applicants_for_the_2024_compliance_assurance_process.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_achieves_key_paperless_processing_initiative_goal_outlines_improvements_for_filing_season_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_advances_innovative_direct_file_project_for_2024_tax_season_free_irs_run_pilot_option_projected_to_be_available_for_eligible_taxpayers_in_13_states.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_advisory_council_issues_2023_annual_report.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_and_security_summit_offer_online_safety_tips_during_national_cybersecurity_awareness_month.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_and_treasury_reach_major_milestone_implementing_key_provisions_using_the_irs_energy_credits_online_elective_pay_and_transferability_tool.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_2024_tax_counseling_for_the_elderly_and_volunteer_income_tax_assistance_program_grants.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_administrative_transition_period_for_new_roth_catch_up_requirement_catch_up_contributions_still_permitted_after_2023.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_delay_in_form_1099_k_reporting_threshold_for_third_party_platform_payments_in_2023_plans_for_a_threshold_of_5000_for_2024_to_phase_in_implementation.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_more_time_for_dealers_and_sellers_of_clean_vehicles_to_submit_time_of_sale_reports.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_plans_for_new_leadership_structure_adjustments_align_with_new_priorities_agency_transformation_work.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_sweeping_effort_to_restore_fairness_to_tax_system_with_inflation_reduction_act_funding_new_compliance_efforts.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_announces_withdrawal_process_for_employee_retention_credit_claims_special_initiative_aimed_at_helping_businesses_concerned_about_an_ineligible_claim_amid_aggressive_marketing_scams.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_beware_of_fake_charities_check_before_donating.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_builders_of_qualified_new_energy_efficient_homes_may_qualify_for_an_expanded_tax_credit_under_section_45l.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_clarifies_rules_for_corporate_alternative_minimum_tax.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_clarifies_rules_for_new_corporate_alternative_minimum_tax.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_delivers_new_capabilities_to_tax_pro_account_latest_expansion_part_of_effort_to_improve_technology_tools_to_help_tax_professionals_serve_clients.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_electronic_tax_administration_advisory_committee_select_8_new_members.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_encourages_employers_to_electronically_file_payroll_tax_returns.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_encourages_truckers_to_e_file_by_august_31_tax_payment_deadline.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_expands_use_of_chatbots_to_help_answer_questions_on_key_notices_expands_on_technology_thats_served_13_million_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_expands_work_on_aggressive_employee_retention_credit_claims_20000_disallowance_letters_being_mailed_more_action_and_voluntary_disclosure_program_coming.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_extends_popular_flexibilities_set_to_expire_electronic_signatures_and_encrypted_email_enhance_the_taxpayer_experience.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_extends_relief_to_farmers_and_ranchers_in_49_states_other_areas_impacted_by_drought_more_time_to_replace_livestock.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_free_dec_14_webinar_to_focus_on_tax_year_2023_form_1099_k_reporting_rules_designed_to_help_reporting_income_through_payment_apps_and_online_marketplaces.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_free_file_now_available_free_service_through_irsgov_available_for_millions_of_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_georgia_taxpayers_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_guidance.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_hawaii_wildfire_victims_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_helps_taxpayers_by_providing_penalty_relief_on_nearly_5_million_2020_and_2021_tax_returns_restart_of_collection_notices_in_2024_marks_end_of_pandemic_related_pause.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_highlights_international_fraud_awareness_week_taxpayers_urged_to_protect_against_scams_schemes.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_honored_with_the_association_for_federal_enterprise_risk_managements_luminary_award.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_independent_office_of_appeals_releases_fiscal_year_2024_priorities_focus_on_improving_taxpayer_service.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_issues_a_frequently_asked_question_for_pass_through_entities_to_report_negative_amounts_electronically_to_the_irs_on_part_ii_of_schedules_k_2_and_k_3.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_issues_guidance_for_the_transfer_of_clean_vehicle_credits_and_updates_frequently_asked_questions.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_issues_guidance_on_state_tax_payments.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_issues_guidance_on_the_incremental_cost_for_the_commercial_clean_vehicle_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_issues_standard_mileage_rates_for_2024_mileage_rate_increases_to_67_cents_a_mile_up_1_point_5_cents_from_2023.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_launches_new_initiatives_using_inflation_reduction_act_funding_to_ensure_large_corporations_pay_taxes_owed_continues_to_improve_service_and_modernize_technology_with_launch_of_business_tax_account.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_looks_to_hire_3700_employees_nationwide_to_help_expand_compliance_for_large_corporations_and_complex_partnerships_experienced_accountants_encouraged_to_apply_for_revenue_agent_positions.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_media_relations_office_contact_number.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_new_voluntary_disclosure_program_lets_employers_who_received_questionable_employee_retention_credits_pay_them_back_at_discounted_rate_interested_taxpayers_must_apply_by_march_22.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_offers_free_nov_16_webinar_on_new_information_return_e_file_threshold_change_taking_effect_next_year.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_opens_free_energy_credit_online_tool_for_sellers_of_clean_vehicles_to_register_for_time_of_sale_reporting_and_dealer_advance_payments_for_the_clean_vehicle_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_opens_free_ira_and_chips_pre_filing_registration_tool_for_organizations_to_register_to_monetize_clean_energy_credits.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_operations_status_of_mission_critical_functions.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_provides_guidance_on_employer_leave_based_donation_programs_that_aid_victims_of_the_wildfires_in_hawaii.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_provides_initial_guidance_to_employers_setting_up_emergency_savings_accounts_for_their_employees.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_provides_tax_inflation_adjustments_for_tax_year_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_publishes_its_fiscal_year_2023_financial_report_receives_award_for_2022_report.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_ramps_up_new_initiatives_using_inflation_reduction_act_funding_to_ensure_complex_partnerships_large_corporations_pay_taxes_owed_continues_to_close_millionaire_tax_debt_cases.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminder_jan_31_filing_deadline_for_employers_to_file_wage_statements_independent_contractor_forms.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminder_make_sure_to_understand_recent_changes_when_buying_a_clean_vehicle.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminder_to_storm_victims_in_3_states_file_and_pay_by_oct_16_most_of_california_parts_of_alabama_and_georgia_affected.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminds_eligible_2020_and_2021_non_filers_to_claim_recovery_rebate_credit_before_time_runs_out.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminds_gig_workers_self_employed_and_others_of_sept_15_third_quarter_estimated_tax_payment_deadline.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminds_taxpayers_jan_16_due_date_for_final_2023_quarterly_estimated_tax_payments.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_reminds_those_aged_73_and_older_to_make_required_withdrawals_from_iras_and_retirement_plans_by_dec_31_notes_changes_in_the_law_for_2023.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_requests_applications_for_2024_etaac_membership.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_requests_comments_on_expanding_tax_certainty_and_issue_resolution_programs_for_business_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_requests_feedback_on_preview_of_proposed_changes_to_form_6765_credit_for_increasing_research_activities.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_security_summit_partners_announce_8th_annual_national_tax_security_awareness_week_begins_nov_27_focus_on_raising_awareness_among_taxpayers_tax_pros_on_security_tips_to_protect_against_identity.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_security_summit_partners_launch_2023_national_tax_security_awareness_week_focusing_on_holiday_scams_protecting_personal_information_as_tax_season_nears.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_security_summit_partners_warn_of_surge_in_new_client_scams_aimed_at_tax_pros_as_2024_filing_season_approaches.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_selects_12_new_irsac_members_for_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_selects_rajiv_uppal_as_new_chief_information_officer_veteran_technology_executive_will_assist_with_ongoing_transformation_work.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_south_carolina_taxpayers_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_statements_and_announcements.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_supports_international_efforts_to_fight_fraud_during_charity_fraud_awareness_week.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_hurricane_lee_in_maine_and_massachusetts_qualify_for_tax_relief_various_deadlines_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_seawater_intrusion_in_parts_of_louisiana_qualify_for_tax_relief_various_deadlines_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_taxpayers_impacted_by_the_terrorist_attacks_in_israel_qualify_for_tax_relief_oct_16_filing_deadline_other_dates_postponed_to_oct_7_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_tax_tips.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_tennessee_taxpayers_impacted_by_storms_and_tornadoes_qualify_for_tax_relief_various_deadlines_postponed_to_june_17.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_those_impacted_by_idalia_qualify_for_tax_relief_oct_16_deadline_other_dates_postponed_to_feb_15.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_to_establish_special_pass_through_organization_to_help_with_high_income_compliance_efforts_new_workgroup_to_blend_current_employees_and_new_hires_to_focus_on_complex_partnerships_other_key_areas.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_updates_frequently_asked_questions_for_the_new_previously_owned_and_qualified_commercial_clean_vehicle_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_updates_frequently_asked_questions_related_to_wrongful_incarceration_of_a_united_states_service_member.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_updates_tax_gap_projections_for_2020_2021_projected_annual_gap_rises_to_688_billion.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_update_for_form_990_t_form_1120_pol_filers_with_upcoming_deadlines_e_file_unavailable_for_small_number_of_organizations_with_earlier_due_dates.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_update_on_audits.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_warns_taxpayers_of_improper_art_donation_deduction_promotions_highlights_common_red_flags.txt
# cleaned: ./data_us/www_irs_gov_newsroom_irs_webinar_on_2023_form_1099_k_rules_now_available_free_online_video_can_help_those_who_get_payments_through_payment_apps_and_online_marketplaces.txt
# cleaned: ./data_us/www_irs_gov_newsroom_most_popular_seminars_at_the_2023_irs_nationwide_tax_forums_now_available_online.txt
# cleaned: ./data_us/www_irs_gov_newsroom_multimedia_center.txt
# cleaned: ./data_us/www_irs_gov_newsroom_national_taxpayer_advocate_delivers_annual_report_to_congress_focuses_on_taxpayer_impact_of_paper_processing_delays.txt
# cleaned: ./data_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_2_security_summit_reminds_tax_pros_about_importance_of_written_security_plans_and_data_breach_response_special_webinar_planned_for_nov_30.txt
# cleaned: ./data_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_3_irs_identity_protection_pin_can_help_avoid_fraud_and_tax_related_identity_theft.txt
# cleaned: ./data_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_4_summit_partners_urge_businesses_to_take_steps_to_prevent_data_loss_fraud.txt
# cleaned: ./data_us/www_irs_gov_newsroom_national_tax_security_awareness_week_day_5_as_tax_season_approaches_irs_security_summit_partners_warn_taxpayers_tax_professionals_to_watch_out_for_emerging_scams_by_email_text_phone.txt
# cleaned: ./data_us/www_irs_gov_newsroom_news_releases_for_current_month.txt
# cleaned: ./data_us/www_irs_gov_newsroom_news_release_and_fact_sheet_archive.txt
# cleaned: ./data_us/www_irs_gov_newsroom_new_school_year_reminder_to_educators_maximum_educator_expense_deduction_is_300_in_2023.txt
# cleaned: ./data_us/www_irs_gov_newsroom_oct_16_tax_filing_extension_deadline_nears_for_millions_of_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_qualified_charitable_distributions_allow_eligible_ira_owners_up_to_100000_in_tax_free_gifts_to_charity.txt
# cleaned: ./data_us/www_irs_gov_newsroom_red_flags_for_employee_retention_credit_claims_irs_reminds_businesses_to_watch_out_for_warning_signs_of_aggressive_promotion_that_can_mislead_people_into_making_improper_erc_claims.txt
# cleaned: ./data_us/www_irs_gov_newsroom_reminder_to_employers_and_employees_educational_assistance_programs_can_be_used_to_help_pay_workers_student_loans_free_irs_webinar_will_offer_details.txt
# cleaned: ./data_us/www_irs_gov_newsroom_savers_credit_can_help_low_and_moderate_income_taxpayers_to_save_more_in_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_security_summit_irs_reminds_tax_pros_to_plan_protect_defend_against_identity_theft_special_summer_series_concludes_with_important_reminders.txt
# cleaned: ./data_us/www_irs_gov_newsroom_september_is_national_preparedness_month_irs_reminds_taxpayers_to_prepare_for_natural_disasters.txt
# cleaned: ./data_us/www_irs_gov_newsroom_taxpayer_guide_to_identity_theft.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_reform_resources.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_relief_in_disaster_situations.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_scamsconsumer_alerts.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_season_2024_irs_launches_tax_professional_awareness_week_focus_on_reminders_challenges_and_training_opportunities_for_experienced_and_new_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_season_rapidly_approaching_get_ready_now_to_file_2023_federal_income_tax_returns_in_early_2024.txt
# cleaned: ./data_us/www_irs_gov_newsroom_tax_updates_and_news_from_the_irs.txt
# cleaned: ./data_us/www_irs_gov_newsroom_the_tax_gap.txt
# cleaned: ./data_us/www_irs_gov_newsroom_the_what_ifs_for_struggling_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_newsroom_to_protect_taxpayers_from_scams_irs_orders_immediate_stop_to_new_employee_retention_credit_processing_amid_surge_of_questionable_claims_concerns_from_tax_pros.txt
# cleaned: ./data_us/www_irs_gov_newsroom_transformation_work_continues_irs_expands_business_tax_account_access_to_s_corporations_partnerships_adds_ability_to_view_business_tax_transcripts.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_and_irs_announce_that_businesses_do_not_have_to_report_certain_transactions_involving_digital_assets_until_regulations_are_issued.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_defining_energy_property.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_on_prevailing_wage_and_apprenticeship_requirements_for_increased_energy_credit_or_deduction_amounts.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_and_irs_issue_proposed_regulations_on_reporting_by_brokers_for_sales_or_exchanges_of_digital_assets_new_steps_designed_to_end_confusion_help_taxpayers_aid_high_income_compliance_work.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_for_the_advanced_manufacturing_production_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_sustainable_aviation_fuel_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_the_qualified_alternative_fuel_vehicle_refueling_property_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_issue_guidance_on_the_tax_credit_for_the_production_of_clean_hydrogen.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_propose_regulations_implementing_disallowance_of_deductions_for_certain_conservation_easement_contributions_by_partnerships_s_corporations.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_provide_guidance_for_certain_clean_energy_producers_related_to_domestic_content_request_additional_comments_for_upcoming_regulations.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_provide_guidance_for_those_who_manufacture_new_clean_vehicles.txt
# cleaned: ./data_us/www_irs_gov_newsroom_treasury_irs_request_public_comments_on_product_identification_number_requirement_to_claim_the_energy_efficient_home_improvement_credit.txt
# cleaned: ./data_us/www_irs_gov_newsroom_volunteers_needed_across_the_country_for_free_tax_services.txt
# cleaned: ./data_us/www_irs_gov_newsroom_whats_hot.txt
# cleaned: ./data_us/www_irs_gov_outreach_connection.txt
# cleaned: ./data_us/www_irs_gov_payments.txt
# cleaned: ./data_us/www_irs_gov_payments_direct_pay.txt
# cleaned: ./data_us/www_irs_gov_payments_eftps_the_electronic_federal_tax_payment_system.txt
# cleaned: ./data_us/www_irs_gov_payments_offer_in_compromise.txt
# cleaned: ./data_us/www_irs_gov_payments_online_payment_agreement_application.txt
# cleaned: ./data_us/www_irs_gov_payments_pay_taxes_on_time.txt
# cleaned: ./data_us/www_irs_gov_payments_pay_your_taxes_by_debit_or_credit_card.txt
# cleaned: ./data_us/www_irs_gov_payments_penalties.txt
# cleaned: ./data_us/www_irs_gov_payments_penalty_relief.txt
# cleaned: ./data_us/www_irs_gov_payments_your_online_account.txt
# cleaned: ./data_us/www_irs_gov_privacy_disclosure_irs_freedom_of_information.txt
# cleaned: ./data_us/www_irs_gov_privacy_disclosure_irs_privacy_policy.txt
# cleaned: ./data_us/www_irs_gov_privacy_disclosure_report_phishing.txt
# cleaned: ./data_us/www_irs_gov_publications_p17.txt
# cleaned: ./data_us/www_irs_gov_publications_p535.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_i1040gi_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p1345_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p3908_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p4268_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p5343_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p5382_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p5424_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p5884_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_p594_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_pdf_pcir230_pdf.txt
# cleaned: ./data_us/www_irs_gov_pub_irs_prior_p5382__2020_pdf.txt
# cleaned: ./data_us/www_irs_gov_refunds.txt
# cleaned: ./data_us/www_irs_gov_refunds_get_your_refund_faster_tell_irs_to_direct_deposit_your_refund_to_one_two_or_three_accounts.txt
# cleaned: ./data_us/www_irs_gov_refunds_tax_season_refund_frequently_asked_questions.txt
# cleaned: ./data_us/www_irs_gov_refunds_what_to_expect_for_refunds_this_year.txt
# cleaned: ./data_us/www_irs_gov_retirement_plans.txt
# cleaned: ./data_us/www_irs_gov_ru.txt
# cleaned: ./data_us/www_irs_gov_ru_businesses.txt
# cleaned: ./data_us/www_irs_gov_ru_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_ru_filing.txt
# cleaned: ./data_us/www_irs_gov_ru_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_ru_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_ru_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_statistics.txt
# cleaned: ./data_us/www_irs_gov_statistics_soi_tax_stats_irs_operations_and_budget.txt
# cleaned: ./data_us/www_irs_gov_submit_power_of_attorney_and_tax_information_authorizations.txt
# cleaned: ./data_us/www_irs_gov_taxpayer_advocate.txt
# cleaned: ./data_us/www_irs_gov_taxpayer_bill_of_rights.txt
# cleaned: ./data_us/www_irs_gov_taxpayer_first_act.txt
# cleaned: ./data_us/www_irs_gov_taxtopics_tc153.txt
# cleaned: ./data_us/www_irs_gov_taxtopics_tc161.txt
# cleaned: ./data_us/www_irs_gov_taxtopics_tc203.txt
# cleaned: ./data_us/www_irs_gov_taxtopics_tc418.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_contacts.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_forms_and_filing_requirements_for_tax_exempt_bonds.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_irs_complaint_or_referral_process_tax_exempt_bonds.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_news.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_post_issuance_compliance.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_published_guidance.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_reference_materials.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_subscription_to_tax_exempt_bond_community_news.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_tax_credit_and_direct_pay_bonds.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_tax_exempt_bonds_community_updates.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_tax_exempt_bonds_faqs_regarding_reissuance.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_teb_post_issuance_compliance_some_basic_concepts.txt
# cleaned: ./data_us/www_irs_gov_tax_exempt_bonds_teb_voluntary_closing_agreement_program.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_annual_filing_season_program.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_certified_professional_employer_organization.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_choosing_a_tax_professional.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_contact_the_return_preparer_program.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_continuing_education_for_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_enrolled_actuaries.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_enrolled_agents.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_enrolled_retirement_plan_agent_program.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_make_a_complaint_about_a_tax_return_preparer.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_office_of_professional_responsibility_and_circular_230.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_practitioner_priority_service_r.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_ptin_requirements_for_tax_return_preparers.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_serve_your_clients.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_stay_compliant.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_tax_pro_account.txt
# cleaned: ./data_us/www_irs_gov_tax_professionals_tax_pro_news_and_resources.txt
# cleaned: ./data_us/www_irs_gov_tax_reform.txt
# cleaned: ./data_us/www_irs_gov_vi.txt
# cleaned: ./data_us/www_irs_gov_vi_businesses.txt
# cleaned: ./data_us/www_irs_gov_vi_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_vi_filing.txt
# cleaned: ./data_us/www_irs_gov_vi_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_vi_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_vi_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_wheres_my_refund.txt
# cleaned: ./data_us/www_irs_gov_zh_hans.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_businesses.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_filing.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_newsroom.txt
# cleaned: ./data_us/www_irs_gov_zh_hans_tax_professionals.txt
# cleaned: ./data_us/www_irs_gov_zh_hant.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_businesses.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_charities_and_nonprofits.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_filing.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_help_telephone_assistance.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_individuals_international_taxpayers.txt
# cleaned: ./data_us/www_irs_gov_zh_hant_tax_professionals.txt

# %%
# Path to the directory containing your text files
input_path = './data_us/'
output_file = 'us_tax_revenue_info.txt'

# Initialize an empty string to store the merged content
merged_content = ''

# Iterate over each file in the directory
for filename in os.listdir(input_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(input_path, filename)

        # Read the content of the file
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

            # Remove newline characters and excessive spaces
            content = content.replace('\n', ' ').replace('\r', '').strip()

        # Append the content of the current file to the merged content
        merged_content += content + ' '  # Adding a space between contents of different files

# Write the merged content to the output file
with open(output_file, 'w', encoding='utf-8') as merged_file:
    merged_file.write(merged_content.strip())  # Remove any leading/trailing whitespace

print("Merged content saved to " + output_file)
# Out:
# Merged content saved to us_tax_revenue_info.txt

# %%
# File path
input_file = 'us_tax_revenue_info.txt'
output_file = 'cleaned_us_tax_revenue_info.txt'

# Read the content of the file
with open(input_file, 'r', encoding='utf-8') as file:
    content = file.read()

# Replace all non-alphanumeric and non-currency symbol characters with a space
cleaned_content = re.sub(r'[^A-Za-z0-9\$\€\£\¥ ]', ' ', content)

# Replace multiple spaces with a single space
cleaned_content = re.sub(r'\s+', ' ', cleaned_content)

# Write the cleaned content to a new file
with open(output_file, 'w', encoding='utf-8') as file:
    file.write(cleaned_content.strip())

print("Cleaned content saved to " + output_file)
# Out:
# Cleaned content saved to cleaned_us_tax_revenue_info.txt
