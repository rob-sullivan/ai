# %% [markdown]
# # Artificial Neural Network
# this ANN is to solve a bank churn problem
# ## data preprocessing
# ### libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### import data

# %%
dataset = pd.read_csv("Churn_Modelling.csv")
#first columns won't help so we need to remove them
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values
print(X)
print(y)

# %% [markdown]
# ### split into training and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
### encode categorical data
## build ANN
### initialise ANN 
### add input layers and hidden layers
### add second hidden layer
### Add output layer
## Train ANN
### compile ANN
### train ANN
## Make predictions
### predict single
### predict on test set
